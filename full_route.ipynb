# %%
# !pip install googlemaps
import pandas as pd # pandas - a powerful data analysis and manipulation library for Python
import requests # Requests is an HTTP library, written in Python, for human beings.
from datetime import datetime
import googlemaps

# %%
#Google Maps API key
apikey = 'AIzaSyDxk6272R8Yu_QDKZRyR27SZBaJKN-_3u0'

# %% [markdown]
# ## Using sample user origin

# %%
#User will input address as text
origin_address = '1512 Shattuck Ave, Berkeley, CA 94709'
dest_address = 'New York University,New York, NY 10003'

# %%
#Use Google Maps to grab latitude and longitude
r = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address="%s"&key=%s'%
                 (origin_address, apikey))
r1=requests.get('https://maps.googleapis.com/maps/api/geocode/json?address="%s"&key=%s'%
                 (dest_address, apikey))
result_o = r.json()['results']
result_d=r1.json()['results']
location_origin = result_o[0]['geometry']['location']
location_destination = result_d[0]['geometry']['location']
o_lat = location_origin['lat']
o_lon = location_origin['lng']
d_lat = location_destination['lat']
d_lon = location_destination['lng']
origin = [o_lat, o_lon]
destination=[d_lat,d_lon]
print(origin)
print(destination)
# Out:
# [37.8798419, -122.2695316]
# [40.72951339999999, -73.9964609]

# %% [markdown]
# ## Using Amadeus to find nearest airport to user's starting location

# %%
pip install amadeus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from amadeus import Client, ResponseError

amadeus = Client(client_id='UmuSC0LY9TgqaZoLDpBR2x74yN0GCahI',
    client_secret='9SbiFzopXFTkVOBz')

# %%
# Nearest airport search, put into a result array
#Need to get live latitude and longitudinal data from Google Maps
origin_address_list = []
dest_address_list=[]
origin_state_list = []
dest_state_list = []
a_lats = []
a_lons = []
b_lats=[]
b_lons=[]
a_iata = []
b_iata = []
try:
    '''
    What relevant airports are there around the origin location?
    '''
    response = amadeus.reference_data.locations.airports.get(longitude=o_lon, latitude=o_lat)
    response1 = amadeus.reference_data.locations.airports.get(longitude=d_lon, latitude=d_lat)
    for i in response.data:
        data_dict = i
#         print(i)
        origin_address_list.append(data_dict['name'])
        origin_state_list.append(data_dict['address']['stateCode'])
        a_lats.append(data_dict['geoCode']['latitude'])
        a_lons.append(data_dict['geoCode']['longitude'])
        a_iata.append(data_dict['iataCode'])
except ResponseError as error:
    raise error
    
try:
    '''
    What relevant airports are there around the destination location?
    '''
    response1 = amadeus.reference_data.locations.airports.get(longitude=d_lon, latitude=d_lat)
    for i in response1.data:
        data_dict1 = i
        print(i)
        dest_address_list.append(data_dict1['name'])
        dest_state_list.append(data_dict1['address']['stateCode'])
        b_lats.append(data_dict1['geoCode']['latitude'])
        b_lons.append(data_dict1['geoCode']['longitude'])
        b_iata.append(data_dict1['iataCode'])
except ResponseError as error:
    raise error
# Out:
# {'type': 'location', 'subType': 'AIRPORT', 'name': 'LAGUARDIA', 'detailedName': 'NEW YORK/NY/US:LAGUARDIA', 'timeZoneOffset': '-04:00', 'iataCode': 'LGA', 'geoCode': {'latitude': 40.77607, 'longitude': -73.87269}, 'address': {'cityName': 'NEW YORK', 'cityCode': 'NYC', 'countryName': 'UNITED STATES OF AMERICA', 'countryCode': 'US', 'stateCode': 'NY', 'regionCode': 'NAMER'}, 'distance': {'value': 11, 'unit': 'KM'}, 'analytics': {'flights': {'score': 25}, 'travelers': {'score': 17}}, 'relevance': 211.41658}
# ...

# %%
print(origin_address_list)
print(a_lats)
print(a_lons)
print(a_iata)
print()
print(dest_address_list)
print(b_lats)
print(b_lons)
print(b_iata)
# Out:
# ['SAN FRANCISCO INTL', 'OAKLAND INTL', 'SAN JOSE MNPL', 'EXECUTIVE', 'INTERNATIONAL', 'BUCHANAN FLD', 'TAHOE INTL', 'CHARLES M SCHULZ', 'FRESNO YOSEMITE INTL', 'MONTEREY REGIONAL']
# [37.61882, 37.72104, 37.36189, 38.51323, 38.69518, 37.98937, 39.50597, 38.5088, 36.77606, 36.5879]
# [-122.3758, -122.2216, -121.9289, -121.4975, -121.5916, -122.058, -119.7731, -122.8139, -119.719, -121.8394]
# ['SFO', 'OAK', 'SJC', 'SAC', 'SMF', 'CCR', 'RNO', 'STS', 'FAT', 'MRY']
#
# ['LAGUARDIA', 'NEWARK LIBERTY INTL', 'JOHN F KENNEDY INTL', 'PHILADELPHIA INTL', 'EDWARD L LOGAN INTL', 'WESTCHESTER COUNTY', 'R REAGAN NAT', 'BALTIMORE/WASH. INTL', 'DULLES INTL', 'BRAINARD']
# [40.77607, 40.69709, 40.63983, 39.87835, 42.36514, 41.06694, 38.85233, 39.17528, 38.94877, 41.74119]
# [-73.87269, -74.17557, -73.77874, -75.24018, -71.01777, -73.7075, -77.0372, -76.66833, -77.4491, -72.64958]
# ['LGA', 'EWR', 'JFK', 'PHL', 'BOS', 'HPN', 'DCA', 'BWI', 'IAD', 'HFD']

# %% [markdown]
# ## Using Amadeus API to calculate cheapest flight cost

# %%
from amadeus import Client, ResponseError
import json

amadeus = Client(
    client_id=' UmuSC0LY9TgqaZoLDpBR2x74yN0GCahI',
    client_secret='9SbiFzopXFTkVOBz'
)

try:
    response = amadeus.shopping.flight_offers_search.get(
        originLocationCode="SFO",
        destinationLocationCode="LGA",
        departureDate='2020-07-01',
        adults=1)
    flight_cost=response.data[0]['price']['total']
    print("The cheapest flight found costs",flight_cost)
except ResponseError as error:
    print(error)
# Out:
# The cheapest flight found costs 155.40

# %% [markdown]
# ## Using Google Maps to create dataframe of nearest airport latitudes and longitudes

# %%
results = []
# locations_latitude = []
# locations_longitude = []
formatted_address = []
state = []
for location_string in origin_address_list:
    r = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address="%s"&key=%s'%
                     (location_string, apikey))
#     print(r.json())
    result = r.json()['results']
#     print(result)
    location = result[0]['geometry']['location']
#     locations_longitude.append(location['lng'])
#     locations_latitude.append(location['lat'])
    formatted_address.append(result[0]['formatted_address'])
    results.append(result)

# %%
df = pd.DataFrame({'address':origin_address_list,'latitude':a_lats,'longitude':a_lons,'iata code':a_iata})
df
# Out:
#                 address  latitude  longitude iata code
# 0    SAN FRANCISCO INTL  37.61882  -122.3758       SFO
# 1          OAKLAND INTL  37.72104  -122.2216       OAK
# 2         SAN JOSE MNPL  37.36189  -121.9289       SJC
# 3             EXECUTIVE  38.51323  -121.4975       SAC
# 4         INTERNATIONAL  38.69518  -121.5916       SMF
# 5          BUCHANAN FLD  37.98937  -122.0580       CCR
# 6            TAHOE INTL  39.50597  -119.7731       RNO
# 7      CHARLES M SCHULZ  38.50880  -122.8139       STS
# 8  FRESNO YOSEMITE INTL  36.77606  -119.7190       FAT
# 9     MONTEREY REGIONAL  36.58790  -121.8394       MRY

# %%
df1 = pd.DataFrame({'address':dest_address_list,'latitude':b_lats,'longitude':b_lons, 'iata code':b_iata})
df1
# Out:
#                 address  latitude  longitude iata code
# 0             LAGUARDIA  40.77607  -73.87269       LGA
# 1   NEWARK LIBERTY INTL  40.69709  -74.17557       EWR
# 2   JOHN F KENNEDY INTL  40.63983  -73.77874       JFK
# 3     PHILADELPHIA INTL  39.87835  -75.24018       PHL
# 4   EDWARD L LOGAN INTL  42.36514  -71.01777       BOS
# 5    WESTCHESTER COUNTY  41.06694  -73.70750       HPN
# 6          R REAGAN NAT  38.85233  -77.03720       DCA
# 7  BALTIMORE/WASH. INTL  39.17528  -76.66833       BWI
# 8           DULLES INTL  38.94877  -77.44910       IAD
# 9              BRAINARD  41.74119  -72.64958       HFD

# %% [markdown]
# ## Calculate distance from each of these airports to user origin

# %%
dist_from_origin = []
time_from_origin = []
dist_from_destination=[]
time_from_destination=[]

# %%
origin
# Out:
# [37.8798419, -122.2695316]

# %%
destination
# Out:
# [40.72951339999999, -73.9964609]

# %%
origin_str = str(o_lat) + "," + str(o_lon)
print(origin_str)
# Out:
# 37.8798419,-122.2695316

# %%
dest_str = str(d_lat) + "," + str(d_lon)
print(dest_str)
# Out:
# 40.72951339999999,-73.9964609

# %%
#Perform request to use the Google Maps API web service
now = datetime.now()
gmaps = googlemaps.Client(key=apikey)

# %%
for idx, row in df.iterrows():
    a_lat = row['latitude']
    a_lon = row['longitude']
    airport_str = str(a_lat) + "," + str(a_lon)
    directions = gmaps.directions(origin = origin_str,destination = airport_str,
                                  mode='driving',departure_time = now)
#     print(directions)
    print(directions[0]['legs'][0]['distance']['text'])
    print(directions[0]['legs'][0]['duration']['text'])
    print(directions[0]['legs'][0]['start_address'])
    print(directions[0]['legs'][0]['end_address'])
    dist_from_origin.append(directions[0]['legs'][0]['distance']['text'])
    time_from_origin.append(directions[0]['legs'][0]['duration']['text'])
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# 25.6 mi
# 38 mins
# 1512 Shattuck Ave, Berkeley, CA 94709, USA
# 4 Domestic Terminals Departures Level, San Francisco, CA 94128, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 15.4 mi
# 28 mins
# 1512 Shattuck Ave, Berkeley, CA 94709, USA
# 178 Air Cargo Way, Oakland, CA 94621, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 46.6 mi
# 58 mins
# 1512 Shattuck Ave, Berkeley, CA 94709, USA
# Norman Y. Mineta San Jose International Airport (SJC), 1701 Airport Blvd, San Jose, CA 95110, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 81.0 mi
# 1 hour 26 mins
# 1512 Shattuck Ave, Berkeley, CA 94709, USA
# 6107 Freeport Blvd, Sacramento, CA 95822, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 82.1 mi
# 1 hour 28 mins
# 1512 Shattuck Ave, Berkeley, CA 94709, USA
# Alaska Airlines - Sacramento, 6900 Airport Blvd, Sacramento, CA 95837, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 22.5 mi
# 37 mins
# 1512 Shattuck Ave, Berkeley, CA 94709, USA
# ...

# %%
for idx, row in df1.iterrows():
    b_lat = row['latitude']
    b_lon = row['longitude']
    airport_d_str = str(b_lat) + "," + str(b_lon)
    directions_d = gmaps.directions(origin = dest_str,destination = airport_d_str,
                                  mode='driving',departure_time = now)
#     print(directions)
    print(directions_d[0]['legs'][0]['distance']['text'])
    print(directions_d[0]['legs'][0]['duration']['text'])
    print(directions_d[0]['legs'][0]['start_address'])
    print(directions_d[0]['legs'][0]['end_address'])
    dist_from_destination.append(directions_d[0]['legs'][0]['distance']['text'])
    time_from_destination.append(directions_d[0]['legs'][0]['duration']['text'])
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
# Out:
# 10.3 mi
# 25 mins
# 50 West 4th Street, New York, NY 10012, USA
# Terminal B, LaGuardia Rd, East Elmhurst, NY 11371, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 13.7 mi
# 28 mins
# 50 West 4th Street, New York, NY 10012, USA
# Terminal C, 3 Brewster Rd, Newark, NJ 07114, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 18.6 mi
# 37 mins
# 50 West 4th Street, New York, NY 10012, USA
# John F. Kennedy International Airport (JFK), Queens, NY 11430, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 104 mi
# 1 hour 51 mins
# 50 West 4th Street, New York, NY 10012, USA
# Airport Terminals E & F, Philadelphia, PA 19153, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 217 mi
# 3 hours 47 mins
# 50 West 4th Street, New York, NY 10012, USA
# 300 Terminal Dr, Boston, MA 02128, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 35.1 mi
# 56 mins
# 50 West 4th Street, New York, NY 10012, USA
# 240 Airport Rd, West Harrison, NY 10604, USA
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 233 mi
# ...

# %%
df['dist from origin'] = dist_from_origin
df['time from origin'] = time_from_origin
df['state'] = origin_state_list

# %%
df1['dist from destination'] = dist_from_destination
df1['time from destination'] = time_from_destination
df1['state'] = dest_state_list

# %%
df
# Out:
#                 address  latitude  longitude iata code dist from origin  \
# 0    SAN FRANCISCO INTL  37.61882  -122.3758       SFO          25.6 mi
# 1          OAKLAND INTL  37.72104  -122.2216       OAK          15.4 mi
# 2         SAN JOSE MNPL  37.36189  -121.9289       SJC          46.6 mi
# 3             EXECUTIVE  38.51323  -121.4975       SAC          81.0 mi
# 4         INTERNATIONAL  38.69518  -121.5916       SMF          82.1 mi
# 5          BUCHANAN FLD  37.98937  -122.0580       CCR          22.5 mi
# 6            TAHOE INTL  39.50597  -119.7731       RNO           212 mi
# 7      CHARLES M SCHULZ  38.50880  -122.8139       STS          64.1 mi
# 8  FRESNO YOSEMITE INTL  36.77606  -119.7190       FAT           186 mi
# 9     MONTEREY REGIONAL  36.58790  -121.8394       MRY           117 mi
#
#   time from origin state
# 0          38 mins    CA
# 1          28 mins    CA
# 2          58 mins    CA
# 3   1 hour 26 mins    CA
# 4   1 hour 28 mins    CA
# ...

# %%
df1
# Out:
#                 address  latitude  longitude iata code dist from destination  \
# 0             LAGUARDIA  40.77607  -73.87269       LGA               10.3 mi
# 1   NEWARK LIBERTY INTL  40.69709  -74.17557       EWR               13.7 mi
# 2   JOHN F KENNEDY INTL  40.63983  -73.77874       JFK               18.6 mi
# 3     PHILADELPHIA INTL  39.87835  -75.24018       PHL                104 mi
# 4   EDWARD L LOGAN INTL  42.36514  -71.01777       BOS                217 mi
# 5    WESTCHESTER COUNTY  41.06694  -73.70750       HPN               35.1 mi
# 6          R REAGAN NAT  38.85233  -77.03720       DCA                233 mi
# 7  BALTIMORE/WASH. INTL  39.17528  -76.66833       BWI                199 mi
# 8           DULLES INTL  38.94877  -77.44910       IAD                249 mi
# 9              BRAINARD  41.74119  -72.64958       HFD                114 mi
#
#   time from destination state
# 0               25 mins    NY
# 1               28 mins    NJ
# ...

# %% [markdown]
# ## Calculate costs to each of these airports

# %%
# dictionary to get full name of state from abbreviation
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
gas_prices = pd.read_csv('gasprices.csv', index_col=0)

# %%
gas_prices.head()
# Out:
#         State  Regular Price  Mid-Grade Price  Premium Price  Diesel Price
# 0      Alaska          2.216            2.426          2.532         2.534
# 1     Alabama          1.647            2.019          2.348         2.383
# 2    Arkansas          1.535            1.880          2.166         2.250
# 3     Arizona          2.285            2.593          2.808         2.659
# 4  California          2.879            3.071          3.186         3.429

# %%
def calc_gas_price(state, city_mpg, highway_mpg, fuel_type, trip_length):
    cost_per_gallon = float(gas_prices[gas_prices['State'] == state][fuel_type])
    avg_mpg = 0.5*(city_mpg + highway_mpg)
    price = (trip_length/avg_mpg)*cost_per_gallon
    return price

# %%
#test function for 2019 Toyota Prius using example from Travel4All notebook
city_mpg = 48
highway_mpg = 43
gas_type = 'Regular Price'

# %%
costs = []
for idx, row in df.iterrows():
    state = row['state']
    
    #get rid of 'mi' and all commas
    trip_length = float(row['dist from origin'][:-3].replace(',',''))
    cost = calc_gas_price(states[state], city_mpg, highway_mpg, gas_type, trip_length)
    costs.append(cost)

# %%
costs1 = []
for idx, row in df1.iterrows():
    state = row['state']
    
    #get rid of 'mi' and all commas
    trip_length1 = float(row['dist from destination'][:-3].replace(',',''))
    cost1 = calc_gas_price(states[state], city_mpg, highway_mpg, gas_type, trip_length1)
    costs1.append(cost1)

# %%
df['cost'] = costs
df
# Out:
#                 address  latitude  longitude iata code dist from origin  \
# 0    SAN FRANCISCO INTL  37.61882  -122.3758       SFO          25.6 mi
# 1          OAKLAND INTL  37.72104  -122.2216       OAK          15.4 mi
# 2         SAN JOSE MNPL  37.36189  -121.9289       SJC          46.6 mi
# 3             EXECUTIVE  38.51323  -121.4975       SAC          81.0 mi
# 4         INTERNATIONAL  38.69518  -121.5916       SMF          82.1 mi
# 5          BUCHANAN FLD  37.98937  -122.0580       CCR          22.5 mi
# 6            TAHOE INTL  39.50597  -119.7731       RNO           212 mi
# 7      CHARLES M SCHULZ  38.50880  -122.8139       STS          64.1 mi
# 8  FRESNO YOSEMITE INTL  36.77606  -119.7190       FAT           186 mi
# 9     MONTEREY REGIONAL  36.58790  -121.8394       MRY           117 mi
#
#   time from origin state       cost
# 0          38 mins    CA   1.619833
# 1          28 mins    CA   0.974431
# 2          58 mins    CA   2.948602
# ...

# %%
df1['cost']=costs1
df1
# Out:
#                 address  latitude  longitude iata code dist from destination  \
# 0             LAGUARDIA  40.77607  -73.87269       LGA               10.3 mi
# 1   NEWARK LIBERTY INTL  40.69709  -74.17557       EWR               13.7 mi
# 2   JOHN F KENNEDY INTL  40.63983  -73.77874       JFK               18.6 mi
# 3     PHILADELPHIA INTL  39.87835  -75.24018       PHL                104 mi
# 4   EDWARD L LOGAN INTL  42.36514  -71.01777       BOS                217 mi
# 5    WESTCHESTER COUNTY  41.06694  -73.70750       HPN               35.1 mi
# 6          R REAGAN NAT  38.85233  -77.03720       DCA                233 mi
# 7  BALTIMORE/WASH. INTL  39.17528  -76.66833       BWI                199 mi
# 8           DULLES INTL  38.94877  -77.44910       IAD                249 mi
# 9              BRAINARD  41.74119  -72.64958       HFD                114 mi
#
#   time from destination state       cost
# 0               25 mins    NY   0.510020
# ...

# %% [markdown]
# ## Calculating the full cost of routes using different combinations of airports

# %%
total_costs = {}
flight_costs = {}

# %%
for idx, row in df[:3].iterrows():
    a_code = row['iata code']
    
    for idx, row2 in df1[:3].iterrows():
        b_code = row2['iata code']
        
        try:
            response = amadeus.shopping.flight_offers_search.get(
                originLocationCode=a_code,
                destinationLocationCode=b_code,
                departureDate='2020-07-01',
                adults=1)
            flight_cost=response.data[0]['price']['total']
            flight_costs[(a_code, b_code)] = flight_cost
            
            driving_cost = row['cost'] + row2['cost']
            total = float(flight_cost) + float(driving_cost)
            total_costs[(a_code, b_code)] = total
            
            
            print("The cheapest flight found from ", a_code, ' to ', b_code, ': ', flight_cost)
            print('total:', total)

        except ResponseError as error:
            print(error)
# Out:
# The cheapest flight found from  SFO  to  LGA :  155.40
# total: 157.52985274725276
# The cheapest flight found from  SFO  to  EWR :  95.40
# total: 97.65063516483517
# The cheapest flight found from  SFO  to  JFK :  130.27
# total: 132.81083956043958
# The cheapest flight found from  OAK  to  LGA :  157.40
# total: 158.88445054945055
# The cheapest flight found from  OAK  to  EWR :  161.40
# total: 163.00523296703298
# The cheapest flight found from  OAK  to  JFK :  161.40
# total: 163.29543736263736
# The cheapest flight found from  SJC  to  LGA :  153.40
# total: 156.85862197802197
# The cheapest flight found from  SJC  to  EWR :  149.40
# total: 152.9794043956044
# The cheapest flight found from  SJC  to  JFK :  127.27
# total: 131.1396087912088

# %%
total_costs
# Out:
# {('SFO', 'LGA'): 157.52985274725276,
#  ('SFO', 'EWR'): 97.65063516483517,
#  ('SFO', 'JFK'): 132.81083956043958,
#  ('OAK', 'LGA'): 158.88445054945055,
#  ('OAK', 'EWR'): 163.00523296703298,
#  ('OAK', 'JFK'): 163.29543736263736,
#  ('SJC', 'LGA'): 156.85862197802197,
#  ('SJC', 'EWR'): 152.9794043956044,
#  ('SJC', 'JFK'): 131.1396087912088}

# %%
flight_costs
# Out:
# {('SFO', 'LGA'): '155.40',
#  ('SFO', 'EWR'): '95.40',
#  ('SFO', 'JFK'): '130.27',
#  ('OAK', 'LGA'): '157.40',
#  ('OAK', 'EWR'): '161.40',
#  ('OAK', 'JFK'): '161.40',
#  ('SJC', 'LGA'): '153.40',
#  ('SJC', 'EWR'): '149.40',
#  ('SJC', 'JFK'): '127.27'}

# %%
#finding cheapest full route

cheapest_a = min(total_costs, key=total_costs.get)
origin_airport = cheapest_a[0]
dest_airport = cheapest_a[1]

print(cheapest_a)
# Out:
# ('SFO', 'EWR')

# %%
#Full route: origin_address -> origin_airport -> dest_airport -> dest_address
print("Start at", origin_address, "and drive to", origin_airport + ".",
     "The cost of this portion of the trip:", df[df['iata code']==origin_airport]['cost'].iloc[0])
print()
print("Take flight from", origin_airport, 'to', dest_airport + ".",
     "The cost of this portion of the trip:", flight_costs[(origin_airport, dest_airport)])
print()
print("Drive from", dest_airport, "to", dest_address + ".",
     "The cost of this portion of the trip:", df1[df1['iata code']==dest_airport]['cost'].iloc[0])
print()
print("The total cost of the trip is:", total_costs[cheapest_a])
# Out:
# Start at 1512 Shattuck Ave, Berkeley, CA 94709 and drive to SFO. The cost of this portion of the trip: 1.6198329670329668
#
# Take flight from SFO to EWR. The cost of this portion of the trip: 95.40
#
# Drive from EWR to New York University,New York, NY 10003. The cost of this portion of the trip: 0.6308021978021978
#
# The total cost of the trip is: 97.65063516483517

# %%
'''
NEXT STEPS: 
1. Is there a way to automate getting the city and highway mpg?
2. Adding in the cost of the rental car (1 day)
3. ML TIME!!!

'''
# Out:
# '\nNEXT STEPS: \n1. Is there a way to automate getting the city and highway mpg?\n2. Adding in the cost of the rental car (1 day)\n3. ML TIME!!!\n\n'
